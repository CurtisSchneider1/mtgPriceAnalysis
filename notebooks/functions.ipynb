# %%
import pandas as pd
import re

# %%
# import import_ipynb
# import analysisMagic
# from analysisMagic import dfm3
dfm3 = pd.read_pickle("dfm3.pkl")

def cardValue(cardName: str):
    cardName = input("Please enter MTG card name: ").strip()

    while not (dfm3["name"].str.lower() == cardName.lower()).any():
        cardName = input("Please enter a valid card name or press ESC to exit: ").strip()
    
    rows = dfm3[dfm3["name"].str.lower() == cardName.lower()]

    return rows["name", "setName", "priceProvider", "price", "avgMarketPrice", "cardFinish", "uuid"]
