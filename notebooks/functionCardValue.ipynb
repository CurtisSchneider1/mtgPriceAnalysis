# %% [markdown]
# ### Card Value Function
# Run the function and enter a card name to see its price from multiple providers (if available) and the average market price for that card per UUID.

# %%
import pandas as pd

# Ensure no outout wrapping.
pd.set_option("display.expand_frame_repr", False)

# Display all in output.
pd.set_option('display.max_rows', None)

dfm3 = pd.read_csv('../data/dataMagic/cleanMagicIndPrices.csv')
# dfm3 = pd.read_pickle("../data/dataMagic/dfm3.pkl")

# %%
def cardValue():
    """ 
    Function to search dfm3 for  search function for price comparison between multiple price providers.

    Args:
        str: User inputted card name.

    Returns:
        values: Each instance of the inputted card based on UUID, pricing information, and average market price.
    """
    # Requires user input and strips unnecessary spaces.
    cardName = input("Please enter MTG card name (or type esc to cancel): ").strip()
    if cardName.lower() == "esc":
        return None
    
    # Requires valid card name.
    while not (dfm3["name"].str.lower() == cardName.lower()).any():
        cardName = input("Please enter a valid card name (or type esc to exit): ").strip()
        if cardName.lower() == "esc":
            return None
    
    rows = dfm3[dfm3["name"].str.lower() == cardName.lower()]
    subset = rows[["name", "setName", "priceProvider", "price",
                   "avgMarketPrice", "cardFinish", "uuid"]]

    return subset

# %%
# Run the function.
# If example card names are needed: Venom, Aladdin, Buster Sword
cardValue()
# Out:
#                 name               setName priceProvider   price  avgMarketPrice cardFinish                                  uuid
# 313466  Buster Sword         Final Fantasy     tcgplayer   34.05           37.03     normal  955cce31-52f1-5f8e-9364-de6014de5f60
# 313467  Buster Sword         Final Fantasy     tcgplayer   55.09           55.04       foil  955cce31-52f1-5f8e-9364-de6014de5f60
# 313468  Buster Sword         Final Fantasy   cardkingdom   44.99           37.03     normal  955cce31-52f1-5f8e-9364-de6014de5f60
# 313469  Buster Sword         Final Fantasy   cardkingdom   54.99           55.04       foil  955cce31-52f1-5f8e-9364-de6014de5f60
# 313470  Buster Sword         Final Fantasy    cardsphere   32.06           37.03     normal  955cce31-52f1-5f8e-9364-de6014de5f60
# 313471  Buster Sword         Final Fantasy     tcgplayer   70.83           74.43     normal  d76e4687-2626-5957-97b8-f1994428ffa9
# 313472  Buster Sword         Final Fantasy     tcgplayer  135.38          147.68       foil  d76e4687-2626-5957-97b8-f1994428ffa9
# 313473  Buster Sword         Final Fantasy   cardkingdom   79.99           74.43     normal  d76e4687-2626-5957-97b8-f1994428ffa9
# 313474  Buster Sword         Final Fantasy   cardkingdom  159.99          147.68       foil  d76e4687-2626-5957-97b8-f1994428ffa9
# 313475  Buster Sword         Final Fantasy    cardsphere   72.47           74.43     normal  d76e4687-2626-5957-97b8-f1994428ffa9
# 317836  Buster Sword  Final Fantasy Promos     tcgplayer   82.30           82.30       foil  acbdca96-9766-5fcb-932e-f87a893c8af9
