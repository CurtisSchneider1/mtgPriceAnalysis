# %% [markdown]
# MTG Card List as of 8/26/25
# Primarily looking to clean and use enough data to identify card prices

# %%
import pandas as pd

# %%
df = pd.read_csv('cards.csv')
pd.set_option('display.max_columns', None)
df.info()

# %%
df.head(3)

# %%
df.shape

# %%
df.value_counts('toughness')

# %%
df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# statistical overview of numbered columns (probably won't need)
df.describe()
# Out:
#          defense    edhrecRank  edhrecSaltiness  faceConvertedManaCost  \
# count  55.000000  97702.000000     72389.000000            4205.000000
# mean    4.654545  10953.975855         0.366867               2.272057
# std     1.004032   8775.520794         0.355103               2.011431
# min     3.000000      1.000000         0.010000               0.000000
# 25%     4.000000   2951.000000         0.120000               0.000000
# 50%     4.000000   9210.000000         0.260000               2.000000
# 75%     5.000000  17951.750000         0.480000               4.000000
# max     7.000000  29730.000000         3.120000              11.000000
#
#        faceManaValue        hand        life       manaValue
# count    4205.000000  119.000000  119.000000   105961.000000
# mean        2.272057    0.084034    1.084034       21.869070
# std         2.011431    1.211385    5.683130     4344.488674
# min         0.000000   -4.000000   -8.000000        0.000000
# ...

# %%
df.loc[0]
# Out:
# artist                                      Pete Venters
# artistIds           d54c4a1a-c0c5-4834-84db-125d341f3ad8
# asciiName                                            NaN
# attractionLights                                     NaN
# availability                                 mtgo, paper
#                                     ...
# type                             Creature — Human Cleric
# types                                           Creature
# uuid                5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# variations          b7c19924-b4bf-56fc-aa73-f586e940bd42
# watermark                                            NaN
# Name: 0, Length: 78, dtype: object

# %%
# To see the card Name column (keep)
df.loc[:, 'name']
# Out:
# 0           Ancestor's Chosen
# 1           Ancestor's Chosen
# 2              Angel of Mercy
# 3              Angel of Mercy
# 4            Angelic Blessing
#                  ...
# 105956          Into the Roil
# 105957    Bloodchief's Thirst
# 105958          Roil Eruption
# 105959       Roiling Regrowth
# 105960       Kargan Warleader
# Name: name, Length: 105961, dtype: object

# %%
# For a full ist of collumns (most of these probably can be dropped)
df.columns
# Out:
# Index(['artist', 'artistIds', 'asciiName', 'attractionLights', 'availability',
#        'boosterTypes', 'borderColor', 'cardParts', 'colorIdentity',
#        'colorIndicator', 'colors', 'defense', 'duelDeck', 'edhrecRank',
#        'edhrecSaltiness', 'faceConvertedManaCost', 'faceFlavorName',
#        'faceManaValue', 'faceName', 'finishes', 'flavorName', 'flavorText',
#        'frameEffects', 'frameVersion', 'hand', 'hasAlternativeDeckLimit',
#        'hasContentWarning', 'hasFoil', 'hasNonFoil', 'isAlternative',
#        'isFullArt', 'isFunny', 'isGameChanger', 'isOnlineOnly', 'isOversized',
#        'isPromo', 'isRebalanced', 'isReprint', 'isReserved', 'isStarter',
#        'isStorySpotlight', 'isTextless', 'isTimeshifted', 'keywords',
#        'language', 'layout', 'leadershipSkills', 'life', 'loyalty', 'manaCost',
#        'manaValue', 'name', 'number', 'originalPrintings',
#        'originalReleaseDate', 'originalText', 'otherFaceIds', 'power',
# ...

# %%
# identify NA and Null values
df.isna().sum()

# %%
# Look for duplicated rows (there are none)
df.duplicated(keep=False).sum()
# Out:
# np.int64(0)

# %% [markdown]
# At first glance, the data is relatively clean. There are no dupes.
# There are a ton of missing values, but that makes sense because spells don't have power/toughness, etc.
# Mostly looking to keep card name and uuid (for joining card values CSV)

# %%
df.head(3)
# Out:
#   availability colorIdentity colorIndicator colors  defense duelDeck  \
# 0  mtgo, paper             W            NaN      W      NaN      NaN
# 1  mtgo, paper             W            NaN      W      NaN      NaN
# 2  mtgo, paper             W            NaN      W      NaN      NaN
#
#    edhrecRank  edhrecSaltiness  faceConvertedManaCost faceFlavorName  \
# 0     23261.0              NaN                    NaN            NaN
# 1     23261.0              NaN                    NaN            NaN
# 2     18316.0             0.12                    NaN            NaN
#
#    faceManaValue faceName finishes flavorName  \
# 0            NaN      NaN  nonfoil        NaN
# 1            NaN      NaN     foil        NaN
# 2            NaN      NaN  nonfoil        NaN
#
#                                   flavorText frameEffects frameVersion  hand  \
# 0                                        NaN          NaN         2003   NaN
# ...

# %%
#Let's drop columns we don't need
df.columns
# Out:
# Index(['availability', 'colorIdentity', 'colors', 'isGameChanger',
#        'isOnlineOnly', 'isOversized', 'isPromo', 'isRebalanced', 'isReprint',
#        'isReserved', 'isStarter', 'isStorySpotlight', 'isTextless',
#        'isTimeshifted', 'keywords', 'language', 'layout', 'leadershipSkills',
#        'life', 'loyalty', 'manaCost', 'manaValue', 'name', 'number',
#        'originalPrintings', 'originalReleaseDate', 'originalText',
#        'otherFaceIds', 'power', 'printings', 'promoTypes', 'rarity',
#        'rebalancedPrintings', 'relatedCards', 'securityStamp', 'setCode',
#        'side', 'signature', 'sourceProducts', 'subsets', 'subtypes',
#        'supertypes', 'text', 'toughness', 'type', 'types', 'uuid',
#        'variations', 'watermark'],
#       dtype='object')

# %%
df = df.drop(df.columns[3:23], axis=1)
