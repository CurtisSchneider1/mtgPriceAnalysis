# %% [markdown]
# ### Best Value Function
# This is great for determining where to best spend money purely based on card value.

# %%
import pandas as pd

# Display all in output.
pd.set_option('display.max_rows', None)

dfm3 = pd.read_csv('../data/dataMagic/cleanMagicIndPrices.csv')
# dfm3 = pd.read_pickle("../data/dataMagic/dfm3.pkl")

# %%
def bestValue(threshold = 0.96):
    """
    This function outputs cards from dfm3 that meet the threshold.

    Args:
        float: Threshold percentage

    Returns:
        values: Those cards whose prices meet the threshold percentage between price and average market price.
    """
    result = dfm3['price'] <= dfm3['avgMarketPrice'] * (1 - threshold)
    
    subset = dfm3.loc[result, ["name", "setName", "priceProvider", "price",
            "avgMarketPrice", "cardFinish", "uuid"]]
    
    return subset

# %%
# Default is 96%.
bestValue(0.97)
# Out:
#                       name                   setName priceProvider  price  \
# 888               Blessing      Limited Edition Beta     tcgplayer   1.31
# 1624    Sunglasses of Urza      Limited Edition Beta     tcgplayer   0.10
# 66954           Levitation             Ninth Edition     tcgplayer   0.03
# 67976            Telepathy             Ninth Edition     tcgplayer   0.05
# 177622      Sunpetal Grove             Ixalan Promos     tcgplayer   0.01
# 253979  Kolaghan Warmonger                  The List     tcgplayer   0.01
# 341214     Living Artifact  30th Anniversary Edition     tcgplayer  19.95
#
#         avgMarketPrice cardFinish                                  uuid
# 888              86.93     normal  c94ff6f2-2694-515d-8c06-b19afc3c037a
# 1624             64.80     normal  1b66c092-e1db-5340-985d-1bf81dac19dd
# 66954             1.76       foil  05e43c46-b937-5349-a521-614b9442bb4d
# 67976             5.02       foil  48de22e9-055f-5ece-aca0-760fc90cb152
# 177622            8.28       foil  6d355e89-ea9a-57ac-b012-2847e45d13c1
# 253979            2.59     normal  1c94f2f4-9a94-52bf-99da-a2a2741ea469
# 341214         3255.17     normal  eda6c34a-4c23-50a8-8ac9-5aae398abd7f
